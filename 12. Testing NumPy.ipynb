# %% [markdown]
# We will import NumPy library

# %%
import numpy as np

# %% [markdown]
# Testing execution speed of python list and numpy

# %%
my_list=list(range(100000))
my_array=np.array(range(100000))

# %%
# %time for _ in range(10): [x*2 for x in my_list]
# Out:
# CPU times: user 114 ms, sys: 12.8 ms, total: 127 ms
# Wall time: 182 ms

# %%
# %time for _ in range(10): [my_array*2]
# Out:
# CPU times: user 2.46 ms, sys: 0 ns, total: 2.46 ms
# Wall time: 6.87 ms

# %%
import torch
torch.cuda.is_available()
# Out:
# True
