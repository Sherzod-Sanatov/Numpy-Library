# %% [markdown]
# 3 dimensional array

# %%
import numpy as np

# %%
data=[[[11,22,33],[44,55,66]],[[77,88,99],[12,34,56]]]
arr=np.array(data)

# %%
data
arr
arr.ndim
# Out:
# 3

# %%
arr
# Out:
# array([[[11, 22, 33],
#         [44, 55, 66]],
#
#        [[77, 88, 99],
#         [12, 34, 56]]])

# %% [markdown]
# Creating numpy arrays

# %%
arr_int=np.array([1,2,3,4,5])
arr_float=np.array([1.0,2.5,3.7,4.2,5.9])
arr_com=np.array([1 + 2j, 3 - 1j, 2 + 4j])

# %% [markdown]
# Identifying data types

# %%
arr_int.dtype
# Out:
# dtype('int64')

# %%
arr_float.dtype
# Out:
# dtype('float64')

# %%
arr_com.dtype
# Out:
# dtype('complex128')

# %% [markdown]
# Convert data types

# %%
arr_int_to_float=arr_int.astype(float)
arr_int_to_float.dtype
# Out:
# dtype('float64')

# %%
arr_float_to_complex=arr_float.astype(complex)
arr_float_to_complex.dtype
# Out:
# dtype('complex128')

# %%
arr_complex_to_float=arr_com.astype(float)
arr_complex_to_float
# Out:
# <ipython-input-14-bb10c3cb5d93>:1: ComplexWarning: Casting complex values to real discards the imaginary part
#   arr_complex_to_float=arr_com.astype(float)
# array([1., 3., 2.])
